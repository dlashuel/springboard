# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt 
import seaborn as sn

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# ## **2.1. Exploring your data**

# %%
# The number of rows and columns 
properties.shape
# Out:
# (317, 49)

# %%
# The first five rows
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %% [markdown]
# *Missing the title for the date column <br>
# *The first row does not correpond to the data

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            316 non-null    datetime64[ns]
#  1   City of London        317 non-null    object
#  2   Barking & Dagenham    317 non-null    object
#  3   Barnet                317 non-null    object
#  4   Bexley                317 non-null    object
#  5   Brent                 317 non-null    object
#  6   Bromley               317 non-null    object
#  7   Camden                317 non-null    object
#  8   Croydon               317 non-null    object
#  9   Ealing                317 non-null    object
#  10  Enfield               317 non-null    object
#  11  Greenwich             317 non-null    object
#  12  Hackney               317 non-null    object
#  13  Hammersmith & Fulham  317 non-null    object
# ...

# %% [markdown]
# *Three unnamed columns with 317 null values (row index 34, 37, 47)

# %%
properties.describe()
# Out:
#        Unnamed: 34  Unnamed: 37  Unnamed: 47
# count          0.0          0.0          0.0
# mean           NaN          NaN          NaN
# std            NaN          NaN          NaN
# min            NaN          NaN          NaN
# 25%            NaN          NaN          NaN
# 50%            NaN          NaN          NaN
# 75%            NaN          NaN          NaN
# max            NaN          NaN          NaN

# %% [markdown]
# *Incorrect data types in the cities columns, objects instead of floats.

# %% [markdown]
# ## 2.2. Cleaning

# %% [markdown]
# ### 2.2.1. Missing the title for the date column

# %% [markdown]
# #### Code

# %%
properties.rename(columns={'Unnamed: 0':'Date'}, inplace=True)

# %% [markdown]
# #### Test

# %%
properties.head(2)
# Out:
#         Date City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
#
# [2 rows x 49 columns]

# %% [markdown]
# ### 2.2.2. The first row does not correpond to the data

# %% [markdown]
# #### Code

# %%
properties.drop(index=0, inplace=True)

# %% [markdown]
# #### Test

# %%
properties.head(3)
# Out:
#         Date City of London Barking & Dagenham   Barnet   Bexley    Brent  \
# 1 1995-01-01          91449            50460.2  93284.5  64958.1  71306.6
# 2 1995-02-01        82202.8            51085.8  93190.2  64787.9  72022.3
# 3 1995-03-01        79120.7              51269  92247.5  64367.5  72015.8
#
#    Bromley  Camden  Croydon   Ealing  ... NORTH WEST YORKS & THE HUMBER  \
# 1  81671.5  120933  69158.2  79885.9  ...    43958.5            44803.4
# 2  81657.6  119509  68951.1  80897.1  ...    43925.4            44528.8
# 3  81449.3  120282  68712.4  81379.9  ...    44434.9            45200.5
#
#   EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND   LONDON SOUTH EAST SOUTH WEST  \
# 1       45544.5       48527.5         56701.6  74435.8    64018.9    54705.2
# 2       46051.6       49341.3         56593.6  72777.9      63715    54356.1
# 3       45383.8       49442.2         56171.2  73896.8    64113.6    53583.1
#
#   Unnamed: 47  England
# 1         NaN  53202.8
# ...

# %% [markdown]
# ### 2.2.3. Three unnamed columns with 317 null values (row index 34, 37, 47)

# %% [markdown]
# #### Code

# %%
properties.drop(columns=['Unnamed: 34', 'Unnamed: 37', 'Unnamed: 47'], inplace=True)

# %% [markdown]
# #### Test

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 316 entries, 1 to 316
# Data columns (total 46 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  316 non-null    datetime64[ns]
#  1   City of London        316 non-null    object
#  2   Barking & Dagenham    316 non-null    object
#  3   Barnet                316 non-null    object
#  4   Bexley                316 non-null    object
#  5   Brent                 316 non-null    object
#  6   Bromley               316 non-null    object
#  7   Camden                316 non-null    object
#  8   Croydon               316 non-null    object
#  9   Ealing                316 non-null    object
#  10  Enfield               316 non-null    object
#  11  Greenwich             316 non-null    object
#  12  Hackney               316 non-null    object
#  13  Hammersmith & Fulham  316 non-null    object
# ...

# %% [markdown]
# ### 2.2.3. Incorrect data types in the cities columns, objects instead of floats.

# %% [markdown]
# #### Code

# %%
for col in properties.columns[1:]:
    properties[col] = properties[col].astype(float)

# %% [markdown]
# #### Test

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 316 entries, 1 to 316
# Data columns (total 46 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  316 non-null    datetime64[ns]
#  1   City of London        316 non-null    float64
#  2   Barking & Dagenham    316 non-null    float64
#  3   Barnet                316 non-null    float64
#  4   Bexley                316 non-null    float64
#  5   Brent                 316 non-null    float64
#  6   Bromley               316 non-null    float64
#  7   Camden                316 non-null    float64
#  8   Croydon               316 non-null    float64
#  9   Ealing                316 non-null    float64
#  10  Enfield               316 non-null    float64
#  11  Greenwich             316 non-null    float64
#  12  Hackney               316 non-null    float64
#  13  Hammersmith & Fulham  316 non-null    float64
# ...

# %%
properties.describe()
# Out:
#        City of London  Barking & Dagenham         Barnet         Bexley  \
# count      316.000000          316.000000     316.000000     316.000000
# mean    442905.735026       166715.547636  315737.924573  197089.590898
# std     251186.702346        80671.004785  146223.441482   89970.404634
# min      77101.208040        50460.226600   90107.234710   63722.700550
# 25%     244592.624875        90144.785675  186753.196975  118718.580150
# 50%     399328.721900       164312.908500  310819.728850  197828.742550
# 75%     725498.783575       211284.798750  449036.775000  258355.336650
# max     939911.647300       315750.633000  549401.174400  364888.340100
#
#                Brent        Bromley         Camden        Croydon  \
# count     316.000000     316.000000     316.000000     316.000000
# mean   281009.932702  262989.007760  484568.387674  217424.747774
# std    139519.165909  117240.998269  247741.080401   98293.612669
# ...

# %% [markdown]
# ## 3. Modeling

# %%
# Overview of the data
properties.head(3)
# Out:
#         Date  City of London  Barking & Dagenham       Barnet       Bexley  \
# 1 1995-01-01     91448.98487         50460.22660  93284.51832  64958.09036
# 2 1995-02-01     82202.77314         51085.77983  93190.16963  64787.92069
# 3 1995-03-01     79120.70256         51268.96956  92247.52435  64367.49344
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
#
#     NORTH EAST   NORTH WEST  YORKS & THE HUMBER  EAST MIDLANDS  WEST MIDLANDS  \
# 1  42076.35411  43958.48001         44803.42878    45544.52227    48527.52339
# 2  42571.98949  43925.42289         44528.80721    46051.57066    49341.29029
# 3  42369.72984  44434.86810         45200.46775    45383.82395    49442.17973
#
# ...

# %% [markdown]
# #### 3.1.1. Average Annual Home Price for Each Boruogh

# %%
# Average home price annually for each boruogh
year = properties['Date'].dt.year
Avg_home_price_year = properties.groupby(year).mean().round(2)[6:]
Avg_home_price_year
# Out:
#       City of London  Barking & Dagenham     Barnet     Bexley      Brent  \
# Date
# 2001       250625.55            88664.06  185563.35  116527.13  157287.40
# 2002       269632.24           112221.91  220746.06  136797.96  185898.15
# 2003       270811.45           142498.93  251212.93  164482.04  216501.76
# 2004       301032.88           158175.98  271854.11  179141.17  236023.44
# 2005       311783.67           163360.78  279459.67  186512.19  241690.07
# 2006       338518.72           167853.34  291337.80  191831.06  253253.44
# 2007       433838.47           184909.81  326915.50  208085.87  286995.35
# 2008       427296.76           187356.87  330023.31  210199.18  292757.92
# 2009       383417.89           156446.90  299103.01  189050.81  264402.05
# 2010       453662.70           166560.71  333128.10  200874.15  289562.70
# 2011       463930.78           163465.14  338978.01  200672.26  298964.55
# 2012       525327.55           165863.91  358627.35  202546.43  314112.76
# ...

# %% [markdown]
# #### 3.1.2. The Annual Increase in Home Price for Each Borough

# %%
# The annual increase in home price for each borough
dic_home = {}
for col in Avg_home_price_year.columns:
    avg_list =[]
    Avg_home_res_index= Avg_home_price_year[col].reset_index(drop=True)
    for i in range(len(Avg_home_res_index)-1):
        avg_list.append(Avg_home_res_index[i+1] - Avg_home_res_index[i])
        avg_list = [round(x, 2) for x in avg_list]
    dic_home[col] = avg_list
                
annual_increase_in_home_price = pd.DataFrame(dic_home)
annual_increase_in_home_price
# Out:
#     City of London  Barking & Dagenham    Barnet    Bexley     Brent  \
# 0         19006.69            23557.85  35182.71  20270.83  28610.75
# 1          1179.21            30277.02  30466.87  27684.08  30603.61
# 2         30221.43            15677.05  20641.18  14659.13  19521.68
# 3         10750.79             5184.80   7605.56   7371.02   5666.63
# 4         26735.05             4492.56  11878.13   5318.87  11563.37
# 5         95319.75            17056.47  35577.70  16254.81  33741.91
# 6         -6541.71             2447.06   3107.81   2113.31   5762.57
# 7        -43878.87           -30909.97 -30920.30 -21148.37 -28355.87
# 8         70244.81            10113.81  34025.09  11823.34  25160.65
# 9         10268.08            -3095.57   5849.91   -201.89   9401.85
# 10        61396.77             2398.77  19649.34   1874.17  15148.21
# 11        44681.16             7869.71  16143.26  10923.83  25542.85
# 12       139376.78            27438.61  55592.74  30989.18  55031.87
# ...

# %% [markdown]
# #### 3.1.3. Top Five Boroughs with the Highest Average Price Increase in the Past Two Decades

# %%
top5_home_avg_p_increase = annual_increase_in_home_price.mean().sort_values(ascending=False).head(5)
top5_home_avg_p_increase
# Out:
# Kensington & Chelsea    41347.2405
# Westminster             32162.5960
# Camden                  26112.3675
# City of London          25568.6000
# Islington               23371.5415
# dtype: float64

# %% [markdown]
# **3.2.1. Visualizing the data**

# %%
top5_home_avg_p_increase.plot(kind='bar', x=home_avg_increase.index, y=home_avg_increase);
plt.xticks(rotation=90);
plt.show()

# %% [markdown]
# #### 3.2.2. The Annual Increase in Home Price for Each Borough, with the average increase in the column title of each borough

# %%
home_avg_increase_all = round(pd.DataFrame(dic_home).mean().sort_values(ascending=False),2)
dict_names_avg = {}
for i in range(len(home_avg_increase_all)):
    indx = home_avg_increase_all.index[i]
    val = home_avg_increase_all.index[i] + '_' +str(home_avg_increase_all.values[i])
    dict_names_avg[indx] = val

Avg_home_price_year_rename = Avg_home_price_year.rename(columns=dict_names_avg)
Avg_home_price_year_rename
# Out:
#       City of London_25568.6  Barking & Dagenham_11231.76  Barnet_17853.38  \
# Date
# 2001               250625.55                     88664.06        185563.35
# 2002               269632.24                    112221.91        220746.06
# 2003               270811.45                    142498.93        251212.93
# 2004               301032.88                    158175.98        271854.11
# 2005               311783.67                    163360.78        279459.67
# 2006               338518.72                    167853.34        291337.80
# 2007               433838.47                    184909.81        326915.50
# 2008               427296.76                    187356.87        330023.31
# 2009               383417.89                    156446.90        299103.01
# 2010               453662.70                    166560.71        333128.10
# 2011               463930.78                    163465.14        338978.01
# ...

# %% [markdown]
# #### 3.2.3. Plotting the Annual Increase in Home Price for Each Borough

# %%
# Avg_home_price_year
# Plotting the average home price annually for each boruogh
plt.figure(figsize=(13,15))
for col in Avg_home_price_year_rename:
    col_ = col.split('_')[0]
    if col_ in home_avg_increase.index:
        Avg_home_price_year_rename[col].plot(kind='line', linewidth=4, linestyle='--');
    else:
        Avg_home_price_year_rename[col].plot(kind='line', linewidth=.5, alpha=.5);
        plt.xticks(ticks=Avg_home_price_year_rename.index)
plt.title('Average Home Price Annually for Each Boruogh')
plt.legend(bbox_to_anchor=(1.02, .95))
plt.show()

# %% [markdown]
# #### 3.2.4. Plotting the Top Five Boroughs with Highest Average Annual Increase in Home Prices in the Past Two Decades

# %%
# Plotting the average home price annually for boroughs of London with the greatest increase 
# in housing prices, on average, over the last two decades
plt.figure(figsize=(15,10))
for col in home_avg_increase.index:
    Avg_home_price_year[col].plot(kind='line');
    plt.xticks(ticks=Avg_home_price_year.index)
plt.title('Average Home Price Annually for Each Boruogh')
plt.legend()
plt.show()

# %% [markdown]
# ### 4. Conclusion
# We can conclude that Kensington & Chelsea has seen the greatest increase in housing prices, on average, over the last two decades.
